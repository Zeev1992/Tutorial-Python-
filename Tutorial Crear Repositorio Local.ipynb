# %% [markdown]
# # Instalar GIT en Linux (Ubuntu, debian, Kali Linux)
#     sudo apt-get update
#     sudo apt-get install git
# ### Verifica que la instalación se haya hecho correctamente usando el comando:
#     git -–version.

# %% [markdown]
# # Ejercicio 1. Crear un repositorio local
# 1. Ahora vamos a crear un nuevo directorio para nuestro repositorio local.
# Cree un myrepo directorio copiando y pegando el __mkdir__ siguiente comando en la terminal:
# ### mkdir mirepo
# 2. Vaya al __mirepo__ copiando y pegando el __cd__ siguiente comando:
# ### cd mirepo
# 3. En este __mirepo__, creemos un nuevo repositorio local de git usando el __git init__ comando. Copie y pegue el siguiente comando en la terminal:
# ### git init
# 4. __Ahora se crea un nuevo repositorio local__, que puede verificar haciendo una lista de directorios pegando el siguiente comando en la ventana de la terminal:
# ### ls -la .git
# El resultado muestra el contenido del __.git__ subdirectorio que alberga el __repositorio local__:
# ![imagen1-2.png](attachment:imagen1-2.png)

# %% [markdown]
# # Ejercicio 2: crear y agregar un archivo al repositorio local
# 1. Ahora vamos a crear un archivo vacío usando el siguiente __touch__ <nombre de archivo> comando:
# ### touch nuevoarchivo
# 2. Agregue este archivo al repositorio usando el siguiente __git add__ comando:
# ### git add nuevoarchivo

# %% [markdown]
# # Ejercicio 3: Confirmar cambios
# 1. Antes de que podamos confirmar nuestros cambios, debemos decirle a __git__ quiénes somos. Podemos hacer esto usando los siguientes comandos:
# ### git config --global user.email "you@example.com"
# ### git config --global user.name "Your Name"
# #### __NOTA:__ Debes escibri tu correo y user name con el que te registraste en Github
# 2. Una vez que el repositorio tenga el archivo creado, confirmemos nuestros cambios usando el siguiente __git commit__ comando. Tenga en cuenta que la confirmación requiere un mensaje que incluimos usando el __-m__ parámetro:
# ### git commit -m "added nuevoarchivo"
# ![imagen2-2.png](attachment:imagen2-2.png)

# %% [markdown]
# # Ejercicio 4: Crear una rama
# NOTA: Nuestra confirmación anterior creó una rama principal predeterminada llamada __master__.
# 1. Para realizar cambios posteriores en nuestro repositorio, creemos una nueva rama en nuestro repositorio local. Copie y pegue el siguiente __git branch__ comando en la terminal para crear una rama llamada __mirabranch__:
# ### git branch mirabranch

# %% [markdown]
# # Ejercicio 5: Obtener una lista de ramas y rama activa
# 1. Verifiquemos qué ramas contiene nuestro repositorio pegando el siguiente __git branch__ comando en la terminal:
# ### git branch

# %% [markdown]
# ![imagen3.png](attachment:imagen3.png)

# %% [markdown]
# # Ejercicio 6: Cambiar a usar una rama diferente
# 1. Dado que ahora queremos trabajar en la nueva rama, emita el siguiente __git checkout__ comando para convertirla en la rama activa para realizar sus cambios:
# ### git checkout mirabranch
# 2. Verifiquemos que la nueva rama ahora sea la rama activa emitiendo el siguiente __git branch__ comando:
# ### git branch
# 3. Tenga en cuenta que el asterisco __*__ ahora está al lado de lo __mirabranch__ que indica que ahora está activo:
# ![image-2.png](attachment:image-2.png)
# #### NOTA: Como acceso directo para crear y usar la rama git branch y luego activarla, git checkout puede usar el acceso directo de la siguiente manera con la -b opción que crea la rama y la activa en un solo paso:
# ### git checkout -b mirabranch

# %% [markdown]
# # Ejercicio 7: Realice cambios en su rama y verifique el estado de los archivos agregados/modificados
# 1. Hagamos algunos cambios en su nueva __rama llamada mirabranch.___ Comience agregando algo de texto __nuevoarchivo__ pegando el siguiente comando en la terminal que agregará la cadena "Aquí hay algo de texto en mi nuevo archivo". en el archivo
# ### echo 'Primera línea de texto en mi nuevoarchivo' >> nuevoarchivo
# 2. Verifique que el texto se haya agregado pegando el siguiente catcomando:
# ### cat nuevoarchivo
# ![image.png](attachment:image.png)
# 3. Ahora vamos a crear otro archivo llamado __readme.md__ usando el siguiente comando:
# ### touch readme.md
# 4. Y ahora agrégalo al repositorio con el siguiente git add comando:
# ### git add readme.md
# 5. Hasta ahora, en nuestra nueva rama, hemos editado __nuevoarchivo__ agregado un archivo llamado __readme.md__. Podemos verificar fácilmente los cambios en nuestra rama actual usando el git status comando:
# ### git status
# 6. El resultado del __git status__ comando muestra que los archivos __readme.md__ se agregaron a la rama y están listos para confirmarse, ya que los agregamos a la rama usando __git add__. Sin embargo, aunque modificamos el archivo llamado, nuevoarchivo no lo agregamos explícitamente usando __git addy__, por lo tanto, no está listo para confirmarse:
# ![image-4.png](attachment:image-4.png)
# 7. Un atajo para agregar todas las modificaciones y adiciones es usar el siguiente __git add__ comando con un asterisco __*__... esto también agregará el archivo modificado nuevoarchivo la rama y lo dejará listo para ser confirmado:
# ### git add *
# 8. Comprobemos el estado de nuevo:
# ### git status
# 9. El resultado ahora muestra que ambos archivos ahora se pueden confirmar:
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Ejercicio 8: confirmar y revisar el historial de confirmaciones
# 1. Ahora que nuestros cambios están listos, __podemos guardarlos en la rama usando el siguiente comando de confirmación con un mensaje que indica los cambios:__
# ### git commit -m "added readme.md modified nuevoarchivo"
# 2. Podemos emitir el siguiente git logcomando para obtener un historial de confirmaciones recientes:
# ### git log
# 3. El registro muestra 2 confirmaciones recientes: la última confirmación __mirabranch__ y la confirmación anterior master:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Ejercicio 9: Revertir cambios confirmados
# 1. A veces, es posible que no pruebe completamente los cambios antes de realizarlos y puede tener consecuencias no deseadas... __puede revertir sus cambios__ usando un __git revert__ comando como el siguiente. Puede especificar la identificación de su confirmación que puede ver en la salida del registro anterior o __usar el atajo HEAD__ para revertir la última confirmación:
# ### git revert HEAD --no-edit
# #### __NOTA:__ Si no especifica el --no-editindicador, es posible que se le presente una pantalla de edición que muestre el mensaje con los cambios que desea revertir. En ese caso, presione la tecla control (o Ctrl) simultáneamente con __X__.
# 2. El resultado muestra que se ha revertido la confirmación más reciente con el __ID especificado__:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Ejercicio 10: combinar cambios en otra rama
# 1. Hagamos un cambio más en su activo actual __mirabranch__ usando los siguientes comandos:
# ### touch goodfile
# ### git add goodfile
# ### git commit -m "added goodfile"
# ### git log
# 2. La salida del registro muestra que el recién agregado __goodfile__ se ha confirmado en la __mirabranch rama__:
# ![image-5.png](attachment:image-5.png)
# 3. __Ahora fusionemos el contenido de mirabranch__ en la __master rama__. Primero __necesitaremos activar la master rama__ usando el siguiente __git checkout__ comando:
# ### git checkout master
# 4. Ahora fusionemos los cambios de __mirabranch__ en maestro:
# ### git merge mirabranch
# ### git log
# 5. La salida y el registro __muestran la fusión exitosa__ de la rama:
# ![image-4.png](attachment:image-4.png)
# 6. Ahora que los cambios se han fusionado en master de la rama, se __mirabranch pueden eliminar__ con el siguiente __git branch__ comando con la __-d__ opción:
# ### git branch -d mirabranch
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Ejercicio 11: Practica por tu cuenta
# 1. Cree un nuevo directorio y una rama llamada __newbranch__
# 2. Hacer __newbranch__ la rama activa
# 3. Crea un archivo __vacío llamado newbranchfile__
# 4. Agregue el archivo recién creado a su rama
# 5. Confirme los cambios en su __newbranch__
# 6. __Revertir__ los últimos cambios confirmados
# 7. Crear un nuevo archivo llamado __newgoodfile__
# 8. Añadir el último archivo a newbranch
# 9. Confirmar los cambios
# 10. Combinar los cambios __newbranch en master__
